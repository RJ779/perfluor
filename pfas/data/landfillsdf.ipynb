# %%
# !pip install pandas openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd 

path = "/Users/riya/Documents/pfas/data/landfills.xlsx"

landfilldf = pd.read_excel(path, sheet_name = 'LMOP Database')
landfilldf=landfilldf.drop_duplicates(subset='Landfill ID')

# %%
selected_columns = landfilldf[['Latitude', 'Longitude', 'Landfill ID', 'Current Landfill Status', 'Waste in Place (tons)', 'Ownership Type', 
                              'Current Project Status', 'LFG Collected (mmscfd)']]

selected_columns.head()
# Out:
#     Latitude  Longitude  Landfill ID Current Landfill Status  \
# 0  41.707000 -70.895000         1833                  Closed
# 1  42.371200 -72.510800          789                  Closed
# 2  41.940000 -71.235000          794                  Closed
# 5  41.661100 -70.391100         2334                  Closed
# 6  42.092537 -72.594646          793                  Closed
#
#    Waste in Place (tons) Ownership Type Current Project Status  \
# 0               900000.0         Public          Low Potential
# 1               525096.0         Public          Low Potential
# 2              1000000.0        Private               Shutdown
# 5              2000000.0         Public          Low Potential
# 6                    NaN         Public               Shutdown
#
#    LFG Collected (mmscfd)
# 0                     NaN
# 1                     NaN
# 2                    0.72
# 5                     NaN
# 6                    0.36

# %%
print(landfilldf)
# Out:
#      GHGRP ID  Landfill ID                          Landfill Name State  \
# 0         NaN         1833                            Acushnet LF    MA
# 1         NaN          789                             Amherst LF    MA
# 2         NaN          794       Attleboro Landfill, Incorporated    MA
# 5         NaN         2334                          Barnstable LF    MA
# 6   1007948.0          793                  Bondi Island Landfill    MA
# 7   1004958.0          774                              Bourne LF    MA
# 8         NaN         1834                           Braintree LF    MA
# 9   1005715.0        20851         Carver-Marion-Wareham Landfill    MA
# 10        NaN          795                             Chatham LF    MA
# 11        NaN          796           Chicopee Landfill (Republic)    MA
# 12  1007669.0          775                Chicopee Landfill (WMI)    MA
# 13  1005039.0          788                          Crapo Hill LF    MA
# ...

# %%
selected_columns.to_csv('landfill.csv')
